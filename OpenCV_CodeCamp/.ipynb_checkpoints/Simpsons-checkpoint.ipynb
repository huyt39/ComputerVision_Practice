# %%
# !pip install caer canaro
# Out:
# Requirement already satisfied: caer in /opt/anaconda3/lib/python3.12/site-packages (2.0.8)
# Requirement already satisfied: canaro in /opt/anaconda3/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: mypy in /opt/anaconda3/lib/python3.12/site-packages (from caer) (1.10.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from caer) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /opt/anaconda3/lib/python3.12/site-packages (from caer) (4.10.0.84)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.12/site-packages (from caer) (4.11.0)
# Requirement already satisfied: tensorflow in /opt/anaconda3/lib/python3.12/site-packages (from canaro) (2.17.0)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from mypy->caer) (1.0.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (3.3.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (2.32.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (1.66.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow->canaro) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow->canaro) (0.43.0)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow->canaro) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow->canaro) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow->canaro) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->canaro) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->canaro) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->canaro) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->canaro) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow->canaro) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow->canaro) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow->canaro) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow->canaro) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow->canaro) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow->canaro) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow->canaro) (0.1.0)

# %%
import os
import caer
import canaro
import numpy as np
import cv2 as cv
import gc

# %%
IMG_SIZE = (80, 80)
channels = 1
char_path = r'archive/simpsons_dataset'

# %%
char_dict = {}
for char in os.listdir(char_path):
    char_dict[char] = len(os.listdir(os.path.join(char_path, char)))
#Sort in descending order:
char_dict = caer.sort_dict(char_dict, descending = True)
char_dict
# Out:
# [('homer_simpson', 2246),
#  ('ned_flanders', 1454),
#  ('moe_szyslak', 1452),
#  ('lisa_simpson', 1354),
#  ('bart_simpson', 1342),
#  ('marge_simpson', 1291),
#  ('krusty_the_clown', 1206),
#  ('principal_skinner', 1194),
#  ('charles_montgomery_burns', 1193),
#  ('milhouse_van_houten', 1079),
#  ('chief_wiggum', 986),
#  ('abraham_grampa_simpson', 913),
#  ('sideshow_bob', 877),
#  ('apu_nahasapeemapetilon', 623),
#  ('kent_brockman', 498),
#  ('comic_book_guy', 469),
#  ('edna_krabappel', 457),
#  ('nelson_muntz', 358),
#  ('lenny_leonard', 310),
#  ('mayor_quimby', 246),
#  ('waylon_smithers', 181),
#  ('maggie_simpson', 128),
#  ('groundskeeper_willie', 121),
#  ('barney_gumble', 106),
#  ('selma_bouvier', 103),
#  ('carl_carlson', 98),
#  ('ralph_wiggum', 89),
#  ('patty_bouvier', 72),
#  ('martin_prince', 71),
#  ('professor_john_frink', 65),
#  ('snake_jailbird', 55),
#  ('cletus_spuckler', 47),
#  ('rainier_wolfcastle', 45),
#  ('simpsons_dataset', 42),
#  ('agnes_skinner', 42),
#  ('sideshow_mel', 40),
#  ('otto_mann', 32),
#  ('fat_tony', 27),
#  ('gil', 27),
#  ('miss_hoover', 17),
#  ('troy_mcclure', 8),
#  ('disco_stu', 8),
#  ('lionel_hutz', 3)]

# %%
characters = []
count = 0
for i in char_dict:
    characters.append(i[0])
    count += 1
    if count >= 10:
        break
characters
# Out:
# ['homer_simpson',
#  'ned_flanders',
#  'moe_szyslak',
#  'lisa_simpson',
#  'bart_simpson',
#  'marge_simpson',
#  'krusty_the_clown',
#  'principal_skinner',
#  'charles_montgomery_burns',
#  'milhouse_van_houten']

# %%
#Create the training data:
train = caer.preprocess_from_dir(char_path, characters, channels = channels, IMG_SIZE = IMG_SIZE, isShuffle = True)
# Out:
# [INFO] Could not find a file to load from. Generating the training data
# ----------------------------------------------
# [INFO] At 1000 files
# [INFO] At 2000 files
# [INFO] 2246 files found in 0.019524097442626953s
# [INFO] At 1000 files
# [INFO] 1454 files found in 0.0045588016510009766s
# [INFO] At 1000 files
# [INFO] 1452 files found in 0.003860950469970703s
# [INFO] At 1000 files
# [INFO] 1354 files found in 0.00439906120300293s
# [INFO] At 1000 files
# [INFO] 1342 files found in 0.00406193733215332s
# [INFO] At 1000 files
# [INFO] 1291 files found in 0.003331899642944336s
# [INFO] At 1000 files
# [INFO] 1206 files found in 0.0035772323608398438s
# [INFO] At 1000 files
# [INFO] 1194 files found in 0.0034360885620117188s
# [INFO] At 1000 files
# [INFO] 1193 files found in 0.0032889842987060547s
# [INFO] At 1000 files
# [INFO] 1079 files found in 0.003139972686767578s
# ----------------------------------------------
# [INFO] 13811 files preprocessed! Took 0m 11s

# %%
len(train) #number of lists
# Out:
# 13811

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (30, 30))
plt.imshow(train[0][0], cmap = 'gray')
plt.show()

# %%
#Separate training set into features and labels:
featureSet, labels = caer.sep_train(train, IMG_SIZE = IMG_SIZE)

# %%
from tensorflow.keras.utils import to_categorical
#Normalize the featureSet ==> (0, 1):
featureSet = caer.normalize(featureSet)
labels = to_categorical(labels, len(characters))

# %%
x_train, x_val, y_train, y_val = caer.train_val_split(featureSet, labels, val_ratio = .2)

# %%
del train
del featureSet
del labels
gc.collect()
# Out:
# 0

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
#Image data generator:
datagen = canaro.generators.imageDataGenerator()
train_gen = datagen.flow(x_train, y_train, batch_size = BATCH_SIZE)
